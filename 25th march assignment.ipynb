# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.head(2)
# Out:
#      Airline    Source Destination  Arrival_Time Duration Total_Stops  \
# 0     IndiGo  Banglore   New Delhi  01:10 22 Mar   2h 50m    non-stop
# 1  Air India   Kolkata    Banglore         13:15   7h 25m     2 stops
#
#   Additional_Info  Price                  Route Dep_Time  Date  Month  Year
# 0         No info   3897              BLR → DEL    22:20    24      3  2019
# 1         No info   7662  CCU → IXR → BBI → BLR    05:50     1      5  2019

# %% [markdown]
# # Q1. Load the flight price dataset and examine its dimensions. How many rows and columns does the dataset have?

# %%
df=pd.read_excel('Flight Ticket Price.xlsx')

# %%
df.shape
# Out:
# (10683, 11)

# %% [markdown]
# ## This dataset has 11 columns and 10683 rows.

# %% [markdown]
# # Q2. What is the distribution of flight prices in the dataset? Create a histogram to visualize the distribution.

# %%
df.describe()
# Out:
#               Price
# count  10683.000000
# mean    9087.064121
# std     4611.359167
# min     1759.000000
# 25%     5277.000000
# 50%     8372.000000
# 75%    12373.000000
# max    79512.000000

# %%
plt.hist(df['Price'])
# Out:
# (array([6.029e+03, 4.390e+03, 1.820e+02, 6.600e+01, 7.000e+00, 1.000e+00,
#         5.000e+00, 2.000e+00, 0.000e+00, 1.000e+00]),
#  array([ 1759. ,  9534.3, 17309.6, 25084.9, 32860.2, 40635.5, 48410.8,
#         56186.1, 63961.4, 71736.7, 79512. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # Q3. What is the range of prices in the dataset? What is the minimum and maximum price?

# %%
df['Price']
# Out:
# 0         3897
# 1         7662
# 2        13882
# 3         6218
# 4        13302
#          ...
# 10678     4107
# 10679     4145
# 10680     7229
# 10681    12648
# 10682    11753
# Name: Price, Length: 10683, dtype: int64

# %%
df.Price.describe()
# Out:
# count    10683.000000
# mean      9087.064121
# std       4611.359167
# min       1759.000000
# 25%       5277.000000
# 50%       8372.000000
# 75%      12373.000000
# max      79512.000000
# Name: Price, dtype: float64

# %% [markdown]
# ## The 'Price' column has a 10683 values starting with a minimum value of 1759 that goes up to the maximum value of 79512.

# %% [markdown]
# # Q4. How does the price of flights vary by airline? Create a boxplot to compare the prices of different airlines.

# %%
sns.boxplot(df['Price'])
# Out:
# <Axes: >

# %% [markdown]
# # Q5. Are there any outliers in the dataset? Identify any potential outliers using a boxplot and describe how they may impact your analysis.

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %% [markdown]
# ## The above boxplot suggests that there are some outliers in the data set.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Source           10683 non-null  object
#  2   Destination      10683 non-null  object
#  3   Arrival_Time     10683 non-null  object
#  4   Duration         10683 non-null  object
#  5   Total_Stops      10682 non-null  object
#  6   Additional_Info  10683 non-null  object
#  7   Price            10683 non-null  int64
#  8   Date_of_Journey  10683 non-null  object
#  9   Route            10682 non-null  object
#  10  Dep_Time         10683 non-null  object
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %% [markdown]
# # Q6. You are working for a travel agency, and your boss has asked you to analyze the Flight Price dataset to identify the peak travel season. What features would you analyze to identify the peak season, and how would you present your findings to your boss?

# %%
df['Date']=df.Date_of_Journey.str.split('/').str[0]
df['Month']=df.Date_of_Journey.str.split('/').str[1]
df['Year']=df.Date_of_Journey.str.split('/').str[2]
df.head()
# Out:
#        Airline    Source Destination  Arrival_Time Duration Total_Stops  \
# 0       IndiGo  Banglore   New Delhi  01:10 22 Mar   2h 50m    non-stop
# 1    Air India   Kolkata    Banglore         13:15   7h 25m     2 stops
# 2  Jet Airways     Delhi      Cochin  04:25 10 Jun      19h     2 stops
# 3       IndiGo   Kolkata    Banglore         23:30   5h 25m      1 stop
# 4       IndiGo  Banglore   New Delhi         21:35   4h 45m      1 stop
#
#   Additional_Info  Price Date_of_Journey                  Route Dep_Time Date  \
# 0         No info   3897      24/03/2019              BLR → DEL    22:20   24
# 1         No info   7662       1/05/2019  CCU → IXR → BBI → BLR    05:50    1
# 2         No info  13882       9/06/2019  DEL → LKO → BOM → COK    09:25    9
# 3         No info   6218      12/05/2019        CCU → NAG → BLR    18:05   12
# 4         No info  13302      01/03/2019        BLR → NAG → DEL    16:50   01
#
#   Month  Year
# 0    03  2019
# 1    05  2019
# 2    06  2019
# ...

# %%
df.drop('Date_of_Journey', axis=1, inplace=True)

# %%
df.head()
# Out:
#        Airline    Source Destination  Arrival_Time Duration Total_Stops  \
# 0       IndiGo  Banglore   New Delhi  01:10 22 Mar   2h 50m    non-stop
# 1    Air India   Kolkata    Banglore         13:15   7h 25m     2 stops
# 2  Jet Airways     Delhi      Cochin  04:25 10 Jun      19h     2 stops
# 3       IndiGo   Kolkata    Banglore         23:30   5h 25m      1 stop
# 4       IndiGo  Banglore   New Delhi         21:35   4h 45m      1 stop
#
#   Additional_Info  Price                  Route Dep_Time Date Month  Year
# 0         No info   3897              BLR → DEL    22:20   24    03  2019
# 1         No info   7662  CCU → IXR → BBI → BLR    05:50    1    05  2019
# 2         No info  13882  DEL → LKO → BOM → COK    09:25    9    06  2019
# 3         No info   6218        CCU → NAG → BLR    18:05   12    05  2019
# 4         No info  13302        BLR → NAG → DEL    16:50   01    03  2019

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Source           10683 non-null  object
#  2   Destination      10683 non-null  object
#  3   Arrival_Time     10683 non-null  object
#  4   Duration         10683 non-null  object
#  5   Total_Stops      10682 non-null  object
#  6   Additional_Info  10683 non-null  object
#  7   Price            10683 non-null  int64
#  8   Route            10682 non-null  object
#  9   Dep_Time         10683 non-null  object
#  10  Date             10683 non-null  object
#  11  Month            10683 non-null  object
#  12  Year             10683 non-null  object
# dtypes: int64(1), object(12)
# memory usage: 1.1+ MB

# %%
df['Date']=df.Date.astype(int)
df['Month']=df.Month.astype(int)
df['Year']=df.Year.astype(int)

# %%
plt.figure(figsize=(20,35))
sns.scatterplot(x='Month' , y='Duration',data=df, hue='Airline')
# Out:
# <Axes: xlabel='Month', ylabel='Duration'>

# %% [markdown]
# # Q7. You are a data analyst for a flight booking website, and you have been asked to analyze the Flight Price dataset to identify any trends in flight prices. What features would you analyze to identify these trends, and what visualizations would you use to present your findings to your team?

# %%
plt.figure(figsize=(30,20))
sns.lineplot(x='Price' , y='Month',data=df, hue='Airline')
# Out:
# <Axes: xlabel='Price', ylabel='Month'>

# %% [markdown]
# # Q8. You are a data scientist working for an airline company, and you have been asked to analyze the Flight Price dataset to identify the factors that affect flight prices. What features would you analyze to identify these factors, and how would you present your findings to the management team?

# %%
sns.scatterplot(x=df['Duration'],y=df['Source'],hue=df['Total_Stops'])
# Out:
# <Axes: xlabel='Duration', ylabel='Source'>

# %% [markdown]
# ## This chart shows that Chennai has all the non-stop flights, therefore the duration is small here.

# %%
plt.figure(figsize=(25,15))
sns.scatterplot(x=df['Duration'],y=df['Price'],hue=df['Total_Stops'])
# Out:
# <Axes: xlabel='Duration', ylabel='Price'>

# %% [markdown]
# ## It shows that the 1stop flights has higher price. Therefore, 1stop flihts have higher demnad.

# %% [markdown]
# # Q9. Load the Google Playstore dataset and examine its dimensions. How many rows and columns does the dataset have?

# %%
df1=pd.read_csv('google_Playstore.csv')
df1.shape
# Out:
# (10839, 16)

# %% [markdown]
# ## This dataset has 16 columns and 10839 rows.

# %% [markdown]
# # Q10. How does the rating of apps vary by category? Create a boxplot to compare the ratings of different app categories.

# %%
df1.head(2)
# Out:
#    Unnamed: 0                                             App        Category  \
# 0           0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1           1                             Coloring book moana  ART_AND_DESIGN
#
#    Rating  Reviews        Size  Installs  Type  Price Content Rating  \
# 0     4.1      159  19000000.0     10000  Free    0.0       Everyone
# 1     3.9      967  14000000.0    500000  Free    0.0       Everyone
#
#                       Genres Current Ver   Android Ver  Udt_Year Udt_Month  \
# 0               Art & Design       1.0.0  4.0.3 and up      2018   January
# 1  Art & Design;Pretend Play       2.0.0  4.0.3 and up      2018   January
#
#    Udt_Date
# 0         7
# 1        15

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10839 entries, 0 to 10838
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      10839 non-null  int64
#  1   App             10839 non-null  object
#  2   Category        10839 non-null  object
#  3   Rating          9365 non-null   float64
#  4   Reviews         10839 non-null  int64
#  5   Size            10839 non-null  float64
#  6   Installs        10839 non-null  int64
#  7   Type            10838 non-null  object
#  8   Price           10839 non-null  float64
#  9   Content Rating  10839 non-null  object
#  10  Genres          10839 non-null  object
#  11  Current Ver     10831 non-null  object
#  12  Android Ver     10837 non-null  object
#  13  Udt_Year        10839 non-null  int64
#  14  Udt_Month       10839 non-null  object
#  15  Udt_Date        10839 non-null  int64
# dtypes: float64(3), int64(5), object(8)
# ...

# %% [markdown]
# # Q11. Are there any missing values in the dataset? Identify any missing values and describe how they may impact your analysis.

# %%
df1.isna().sum()
# Out:
# Unnamed: 0           0
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               0
# Current Ver          8
# Android Ver          2
# Udt_Year             0
# Udt_Month            0
# Udt_Date             0
# dtype: int64

# %% [markdown]
# ## There are 1474 missing values in the 'Rating' column where in 'Type' columns has 1, 'Current Ver' has 8 and 'Android Ver' has 2 missing values.

# %% [markdown]
# ## These missing values has a huge impcat in terms of coming to a conclusion as this missing values will provide some errors in the visualization.

# %% [markdown]
# # Q12. What is the relationship between the size of an app and its rating? Create a scatter plot to visualize the relationship.

# %%
sns.heatmap(df1.corr(), annot=True)
# Out:
# C:\Users\halde\AppData\Local\Temp\ipykernel_58924\3238813197.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df1.corr(), annot=True)
# <Axes: >

# %% [markdown]
# ## It shows that the size and rating has a high positive correlationship.

# %%
sns.lineplot(x='Size', y='Rating', data=df1)
# Out:
# <Axes: xlabel='Size', ylabel='Rating'>

# %% [markdown]
# # Q13. How does the type of app affect its price? Create a bar chart to compare average prices by app type.

# %%
plt.figure(figsize=(30,15))
sns.lineplot(x='Category', y='Price', data=df1)
# Out:
# <Axes: xlabel='Category', ylabel='Price'>

# %%
plt.figure(figsize=(30,15))
sns.barplot(y='Price', data=df1, x='Category')
# Out:
# <Axes: xlabel='Category', ylabel='Price'>

# %% [markdown]
# ## It shows that the Finance apps has the highest Price.

# %% [markdown]
# # Q14. What are the top 10 most popular apps in the dataset? Create a frequency table to identify the apps with the highest number of installs.

# %%
df1['Category'].nunique()
# Out:
# 33

# %%
category= pd.DataFrame(df1['Category'].value_counts())
category.rename(columns= {'Category': 'Count'}, inplace = True)

# %%
category[:10]
# Out:
#                  Count
# FAMILY            1972
# GAME              1144
# TOOLS              842
# MEDICAL            463
# BUSINESS           460
# PRODUCTIVITY       424
# PERSONALIZATION    392
# COMMUNICATION      387
# SPORTS             384
# LIFESTYLE          382

# %%
fre_table=pd.DataFrame([df1['Category'],df1['Installs']])

# %%
fre_table
# Out:
#                    0               1               2               3      \
# Category  ART_AND_DESIGN  ART_AND_DESIGN  ART_AND_DESIGN  ART_AND_DESIGN
# Installs           10000          500000         5000000        50000000
#
#                    4               5               6               7      \
# Category  ART_AND_DESIGN  ART_AND_DESIGN  ART_AND_DESIGN  ART_AND_DESIGN
# Installs          100000           50000           50000         1000000
#
#                    8               9      ...                10829    10830  \
# Category  ART_AND_DESIGN  ART_AND_DESIGN  ...  MAPS_AND_NAVIGATION  WEATHER
# Installs         1000000           10000  ...                 5000   100000
#
#                         10831   10832     10833   10834   10835    10836  \
# Category  BOOKS_AND_REFERENCE  FAMILY  BUSINESS  FAMILY  FAMILY  MEDICAL
# Installs                 1000     500        10    5000     100     1000
#
#                         10837      10838
# ...

# %% [markdown]
# # Q15. A company wants to launch a new app on the Google Playstore and has asked you to analyze the Google Playstore dataset to identify the most popular app categories. How would you approach this task, and what features would you analyze to make recommendations to the company?

# %%
category= pd.DataFrame(df1['Category'].value_counts())
category.rename(columns= {'Category': 'Count'}, inplace = True)
category[:10]
# Out:
#                  Count
# FAMILY            1972
# GAME              1144
# TOOLS              842
# MEDICAL            463
# BUSINESS           460
# PRODUCTIVITY       424
# PERSONALIZATION    392
# COMMUNICATION      387
# SPORTS             384
# LIFESTYLE          382

# %%
plt.figure(figsize=(35,20))
sns.lineplot(x=df1['Category'], y=df1['Rating'])
# Out:
# <Axes: xlabel='Category', ylabel='Rating'>

# %%
data=pd.DataFrame(df1['Category'], df1['Rating'])
data
# Out:
#               Category
# Rating
# 4.1                NaN
# 3.9                NaN
# 4.7                NaN
# 4.5                NaN
# 4.3                NaN
# ...                ...
# 4.5                NaN
# 5.0     ART_AND_DESIGN
# NaN                NaN
# 4.5                NaN
# 4.5                NaN
#
# [10839 rows x 1 columns]
